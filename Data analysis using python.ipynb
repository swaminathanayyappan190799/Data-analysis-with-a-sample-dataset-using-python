# %%
import pandas as pd
import numpy as np
x=pd.read_csv('F:/STUDY MATERIALS/Core elective selection list/CSE-B/Core elective selection for CSE - _B_ [2017 -2021] batch VII semester.csv')

# %% [markdown]
# # Receiving first five records

# %%
x.head()
# Out:
#                          Timestamp                         Username  \
# 0  2020/04/15 11:40:38 AM GMT+5:30          subranaveen08@gmail.com
# 1  2020/04/15 11:57:41 AM GMT+5:30       pradeepadhanam50@gmail.com
# 2  2020/04/15 11:58:58 AM GMT+5:30  sabarishsubramaniam23@gmail.com
# 3  2020/04/15 12:00:46 PM GMT+5:30          nivimohan2001@gmail.com
# 4  2020/04/15 12:03:10 PM GMT+5:30         malarvizhik241@gmail.com
#
#   Name of the student   Roll number   Register number  \
# 0        S.Naveenkumar            40          1714401
# 1           Pradeepa P            17          1714159
# 2           Sabarish S            20          1714164
# 3            Nivetha V            12          1714154
# 4         Malarvizhi k             5          1714147
#
#            Elective - II        Elective - III
# 0  Artificial Intelligence    Machine learning
# 1  Artificial Intelligence    Machine learning
# 2  Artificial Intelligence  Python programming
# ...

# %% [markdown]
# # Count the number of students who had choosen 'Artificial Intelligence' in their Elective-II

# %%
x.columns
# Out:
# Index(['Timestamp', 'Username', 'Name of the student ', 'Roll number ',
#        'Register number', 'Elective - II  ', 'Elective - III'],
#       dtype='object')

# %%
len(x[x['Elective - II  ']=='Artificial Intelligence'])
# Out:
# 14

# %% [markdown]
# # List the students who had selected 'Artificial Intelligence' in their elective - II and 'Machine learning' in their elective - III

# %%
x[(x['Elective - II  ']=='Artificial Intelligence') & (x['Elective - III']=='Machine learning')]
# Out:
#                           Timestamp                       Username  \
# 0   2020/04/15 11:40:38 AM GMT+5:30        subranaveen08@gmail.com
# 1   2020/04/15 11:57:41 AM GMT+5:30     pradeepadhanam50@gmail.com
# 20  2020/04/15 12:26:47 PM GMT+5:30  swamynathanayyappan@gmail.com
#
#    Name of the student   Roll number   Register number  \
# 0         S.Naveenkumar            40          1714401
# 1            Pradeepa P            17          1714159
# 20        Swaminathan A            31          1714175
#
#             Elective - II      Elective - III
# 0   Artificial Intelligence  Machine learning
# 1   Artificial Intelligence  Machine learning
# 20  Artificial Intelligence  Machine learning

# %% [markdown]
# # Remove the 29th index temporarily

# %%
x.drop(29)
# Out:
#                           Timestamp                           Username  \
# 0   2020/04/15 11:40:38 AM GMT+5:30            subranaveen08@gmail.com
# 1   2020/04/15 11:57:41 AM GMT+5:30         pradeepadhanam50@gmail.com
# 2   2020/04/15 11:58:58 AM GMT+5:30    sabarishsubramaniam23@gmail.com
# 3   2020/04/15 12:00:46 PM GMT+5:30            nivimohan2001@gmail.com
# 4   2020/04/15 12:03:10 PM GMT+5:30           malarvizhik241@gmail.com
# 5   2020/04/15 12:06:19 PM GMT+5:30             varunmahi777@gmail.com
# 6   2020/04/15 12:06:34 PM GMT+5:30        vinothinimyilsamy@gmail.com
# 7   2020/04/15 12:07:05 PM GMT+5:30         mirudubasini2000@gmail.com
# 8   2020/04/15 12:08:25 PM GMT+5:30            nitishmani111@gmail.com
# 9   2020/04/15 12:09:12 PM GMT+5:30      Krishnaveniraja1999@gmail.com
# 10  2020/04/15 12:13:50 PM GMT+5:30     yakshivenkatesh32189@gmail.com
# 11  2020/04/15 12:16:57 PM GMT+5:30  seetharaman.jayaraman21@gmail.com
# ...

# %% [markdown]
# # Find the rollnumber and E-mail Id (Username) of Swaminathan

# %%
x[x['Name of the student ']=='Swaminathan A'][['Roll number ','Username']]
# Out:
#     Roll number                        Username
# 20            31  swamynathanayyappan@gmail.com

# %% [markdown]
# # Find the person who is having the max roll number

# %%
max=x['Roll number '].max()
x[x['Roll number ']==max]
# Out:
#                          Timestamp                 Username  \
# 0  2020/04/15 11:40:38 AM GMT+5:30  subranaveen08@gmail.com
#
#   Name of the student   Roll number   Register number  \
# 0        S.Naveenkumar            40          1714401
#
#            Elective - II      Elective - III
# 0  Artificial Intelligence  Machine learning

# %% [markdown]
# # Find the member count for each and ever

# %%
x['Elective - II  '].value_counts()
# Out:
# XML and Web services       25
# Artificial Intelligence    14
# Mobile Ad hoc Networks      1
# Name: Elective - II  , dtype: int64
